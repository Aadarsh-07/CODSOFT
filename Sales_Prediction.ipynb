# %% [markdown]
# <a href="https://colab.research.google.com/github/Aadarsh-07/CODSOFT/blob/main/Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn. linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
import os

# %%
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount = True)
notebook_dir = '/content/drive/My Drive/Colab Notebooks'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
for item in os.listdir(notebook_dir):
    item_path = os.path.join(notebook_dir, item)
    if os.path.isdir(item_path):
        print(item)
# Out:
# Train
# Sentiment
# Iris
# Titanic
# Sales_Prediction

# %%
os.chdir(notebook_dir)

# Verify the current directory
print("Current directory:", os.getcwd())

# Define the directory path
test_directory = 'Sales_Prediction'

# Change the current directory
os.chdir(test_directory)

# Verify the current directory
print("Current directory:", os.getcwd())

# Construct the full file path
file_path = os.path.join(notebook_dir, test_directory, 'advertising.csv')

df= pd.read_csv(file_path)
# Out:
# Current directory: /content/drive/My Drive/Colab Notebooks
# Current directory: /content/drive/My Drive/Colab Notebooks/Sales_Prediction

# %%
df.sample(5)
# Out:
#         TV  Radio  Newspaper  Sales
# 130    0.7   39.6        8.7    1.6
# 179  165.6   10.0       17.6   17.6
# 144   96.2   14.8       38.9   12.3
# 124  229.5   32.3       74.2   19.7
# 29    70.6   16.0       40.8   10.5

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
X = df.iloc[:,0:3]
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
Y = df.iloc[:,-1]
Y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
# 79     11.0
# 197    14.8
# 38     10.1
# 24      9.7
# 122    16.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    17.6
# 102    19.8
# Name: Sales, Length: 160, dtype: float64

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65     11.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      15.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %% [markdown]
# **Linear Regression**

# %%
model=LinearRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8711618087534039

# %% [markdown]
# **Analyzing Data by Scatter Plot**

# %%
plt.scatter(y_test,y_pred,c='r')

# %% [markdown]
# **K-NearestNeighbour**

# %%
model=KNeighborsClassifier()
model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6875

# %% [markdown]
# **Random Forest Regression**

# %%
model=RandomForestRegressor()
model.fit(x_train_scaled,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.870770615183246
